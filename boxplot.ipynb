# %% [markdown]
# <a href="https://colab.research.google.com/github/Hari2020codes/Machine-Learning/blob/main/boxplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
data=[7,15,13,17,19,21,22,18,15,17,20,23,2,30]
plt.boxplot(data)
plt.title('sample box plot')
plt.ylabel('values')
plt.show()
