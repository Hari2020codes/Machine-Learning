# %% [markdown]
# <a href="https://colab.research.google.com/github/Hari2020codes/Machine-Learning/blob/main/bubbleplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # bubble plot
# import matplotlib.pyplot as plt
# x=[5,7,8,7,2,17,2,9,4,11]
# y=[99,86,87,88,100,86,103,87,94,78]
# colors=[0,10,20,30,40,45,50]
# sizes=[200,400,600,800,1000,1200,1400,300,100]
#
# <!-- # Ensure colors and sizes match the length of x and y
# target_len = len(x)
#
# # Extend colors list if its length is less than target_len
# if len(colors) < target_len:
#     colors.extend([colo
#
# ```
# # This is formatted as code
# ```
#
# rs[-1]] * (target_len - len(colors)))
#
# # Extend sizes list if its length is less than target_len
# if len(sizes) < target_len:
#     sizes.extend([sizes[-1]] * (target_len - len(sizes))) -->
#
# plt.scatter(x,y,s=sizes,alpha=1,color='violet')
# plt.title('sample scaterr plot')
# plt.xlabel('x axis')
# plt.ylabel('y axis')
# plt.show()

# %%
# bubble plot
import matplotlib.pyplot as plt
x=[5,7,8,7,2,17,2,9,4,11]
y=[99,86,87,88,100,86,103,87,94,78]
colors=[0,10,20,30,40,45,50]
sizes=[200,400,600,800,1000,1200,1400,300,100,50]

# <!-- # Ensure colors and sizes match the length of x and y
# target_len = len(x)

# # Extend colors list if its length is less than target_len
# if len(colors) < target_len:
#     colors.extend([colors[-1]] * (target_len - len(colors)))

# # Extend sizes list if its length is less than target_len
# if len(sizes) < target_len:
#     sizes.extend([sizes[-1]] * (target_len - len(sizes))) -->

plt.scatter(x,y,s=sizes,alpha=1,color='violet')
plt.title('bubble plot')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[5,7,8,7,2,17,2,9,4,11]
y=[99,86,87,88,100,86,103,87,94,78]
plt.scatter(x,y,color='blue',marker='o')
plt.title('sample scaterr plot')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()
